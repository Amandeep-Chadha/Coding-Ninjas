# %% [markdown]
# # Project
#
# This project involves querying information from "TMDb" API. It demostrates my understand of APIs as well as JSON objects. I have also used Pandas for parsing through the results quickly.

# %% [markdown]
# ## Qset 1:
# Querying on Movies

# %%
#Q1: Find id of movie "Andhadhun" using TMDb API.
import requests

url = "https://api.themoviedb.org/3/search/movie?query=Andhadhun&include_adult=false&language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "token"
}

response = requests.get(url, headers=headers)

print(response.json()['results'][0]['id'])

#Q2: Fetch the company id of company 'Marvel Studios' suing TMDb.
url = "https://api.themoviedb.org/3/search/company?query=marvel&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "token"
}

response = requests.get(url, headers=headers)

for i in (response.json()['results']):
    if i['name'] == 'Marvel Studios':
        print(i['id'])

#Q3 Find the vote count and vote average of the movie "3 Idiiots" using the TMDb API.
import requests

url = "https://api.themoviedb.org/3/movie/20453?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "token"
}

response = requests.get(url, headers=headers)

print(response.json()['vote_count'], response.json()['vote_average'])

#Q4 Fetch the top rated english movies in the US region using the TMDb API. From the result, print the first 10 movies which have original language as english. Also print their genres.
import requests
import pandas as pd

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1&region=US"

headers = {
    "accept": "application/json",
    "Authorization": "token"
}

response = requests.get(url, headers=headers)

results = []
item = 0
while len(results) < 10:
    
    if (response.json()['results'][item]['original_language']) == 'en':
        results.append(response.json()['results'][item])
    item += 1

url = "https://api.themoviedb.org/3/genre/movie/list?language=en"

headers = {
    "accept": "application/json",
    "Authorization": "token"
}

response = requests.get(url, headers=headers)

df1 = pd.DataFrame(response.json()['genres'])
df1.index = df1.id
df1.drop(columns=['id'], inplace = True)
for i in results:
    print(i['original_title'], ' -', end = ' ')
    for j in i['genre_ids']:
        print(df1.loc[j][0], end = ', ')
    print('')
# Out:
# 534780

# %% [markdown]
# ## Qset 2:
# Queries on People

# %%
#Q1 Find the name and birthplace of the present most popular person according to TMDb API.
import requests
import pandas as pd

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1&region=US"

headers = {
    "accept": "application/json",
    "Authorization": "token"
}

response = requests.get(url, headers=headers)

results = []
item = 0
while len(results) < 10:
    
    if (response.json()['results'][item]['original_language']) == 'en':
        results.append(response.json()['results'][item])
    item += 1

url = "https://api.themoviedb.org/3/genre/movie/list?language=en"

headers = {
    "accept": "application/json",
    "Authorization": "token"
}

response = requests.get(url, headers=headers)

df1 = pd.DataFrame(response.json()['genres'])
df1.index = df1.id
df1.drop(columns=['id'], inplace = True)
for i in results:
    print(i['original_title'], ' -', end = ' ')
    for j in i['genre_ids']:
        print(df1.loc[j][0], end = ', ')
    print('')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ...

# %%
#Q2 Fetch the Instagram and Twitter handle of Indian Actress "Alia Bhatt".
import requests

url = "https://api.themoviedb.org/3/person/1108120/external_ids"

headers = {
    "accept": "application/json",
    "Authorization": "token"
}

response = requests.get(url, headers=headers)

print(response.json()['instagram_id'], response.json()['twitter_id'])

#Q3 Fetch the names of the character played by Tom Cruise in the movies:
import requests
import pandas as pd

url = "https://api.themoviedb.org/3/person/500/movie_credits?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "token"
}

response = requests.get(url, headers=headers)
array = ['Top Gun', 'Mission: Impossible - Fallout', 'Minority Report', 'Edge of Tomorrow']

df1 = pd.DataFrame(response.json()['cast'])
list1 = df1['character'][df1['original_title'].isin(array)].values
print(list1[1])
print(list1[3]) 
print(list1[0]) 
print(list1[2])

#Q4 Did James McAvoy playa  role in the movie Deadpool 2. Print Yes or No.
import requests

url = "https://api.themoviedb.org/3/person/5530/movie_credits?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "token"
}

response = requests.get(url, headers=headers)
present = False
for i in (response.json()['cast']):
    if i['original_title'] == 'Deadpool 2':
        present = True
if present:
    print('Yes')
else:
    print('No')

#Q5 Using the result obtained in previous question, find out if James McAvoy was credited for his role in movie Deadpool 2. Print Yes or No.
import requests

url = "https://api.themoviedb.org/3/movie/383498/credits?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "token"
}

response = requests.get(url, headers=headers)
credit = False

for i in (response.json()['cast']):
    if i['name'] == 'James McAvoy':
        credit = True
if credit:
    print('No')
else:
    print('Yes')

# %% [markdown]
# ## Qset 3:
# Querying on tv shows

# %%
#Q1 Fetch the overvuew of the TV Show. "FRIENDS" using TMDb API.

import requests

url = "https://api.themoviedb.org/3/search/tv?query=FRIENDS&include_adult=false&language=en-US&page=1"
headers = {
    "accept": "application/json",
    "Authorization": "token"
}

response = requests.get(url, headers=headers)

print(response.json()['results'][0]['overview'])
print(response.json()['results'][1]['overview'])


#Q2 Fetch the name and air date of S06E05 of the TV Show, 'The Big Bang Theory' form TMDb API.
import requests

url = "https://api.themoviedb.org/3/tv/1418/season/6?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "token"
}

response = requests.get(url, headers=headers)

for i in (response.json()['episodes']):
    if i['episode_number'] == 5:
        print(i['name']," - ", i['air_date'])
        
#Q3 Fetch the trending TV Shows for the week from the TMDb API and print the taglines of the top 5 shows. If there is no tagline, print 'Empty' instead

import requests

url = "https://api.themoviedb.org/3/trending/tv/week?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "token"
}
response = requests.get(url, headers=headers)
results = []
for i in range(5):
    results.append(response.json()['results'][i]['id'])

for i in results:
    url = "https://api.themoviedb.org/3/tv/{0}?language=en-US".format(i)
    response = requests.get(url, headers=headers)
    if not response.json()['tagline']:
        print('Empty')
    else:
        print(response.json()['tagline'])

# %%
#Q4 Print the names of all the TV shows to be aired today whose original language is english.
import requests

# Assign the API key and link to variables
api_key = "e226f4a5f5bace766952aa0d17182959"
api_link = "https://api.themoviedb.org/3"

# Set the parameters for the request
params = {'language':"en" , 'api_key':api_key}

# Set the headers for the request
headers = {'Accept': 'application/json'}

# Send the request to get the TV shows airing today
response = requests.get(api_link + "/tv/airing_today/", headers = headers, params = params)

#Get the response data in JSON format
data= response.json()

# Get the total number of pages in the response
page_number = data.get('total_pages')

# Loop through each page of the response
for i in range(1, page_number + 1):
    
    # Set the parameters for the request to get the current page of TV shows
    params = {'language': 'en', 'api_key': api_key, 'page': i}

    # Send the request to get the current page of TV shows
    response = requests.get(api_link + "/tv/airing_today/", headers=headers, params=params)

    # Get the response data in JSON format
    data = response.json()

    # Get the TV shows from the current page
    results = data.get('results')

    # Loop through each TV show on the current page
    for result in results:
    
        # Check if the TV show's original language is English
        if result.get('original_language') == 'en':
        
            # Print the name of the TV show
            print(result.get('name'))

# %%
#Q5 Count the nnumber of males and females in the cast of "Money Heist" using TMDb API.
import requests
men_count = {'count'}
women_count = {'count'}


url = "https://api.themoviedb.org/3/tv/71446/credits"

headers = {
    "accept": "application/json",
    "Authorization": "token"
}

response = requests.get(url, headers=headers)

for j in response.json()['cast']:
    if j['gender'] == 2:
        men_count.add(j['name'])
    else:
        women_count.add(j['name'])
print(len(men_count)-1, len(women_count)-1)
